# %% [markdown]
# ## Chapter 1
#
# 1.1.4 - Prove using induction:
#
# If U and V $\in$ $\tau$ then U $\cap$ V $\in$ $\tau$
#
# For n=2 $\bigcap_{n} V_n \in \tau $
#
# For n=k assume $\bigcap_{k-1} V_{k-1} \in \tau $
#
# Then $\bigcap_{n} V_n = V_k \bigcap (\bigcap_{k-1}V_{k-1}) \in \tau $
#
# 1.1.5 Pove that ($\mathbb{R}, \tau$) is a topology for the following sets $\tau$:
#
# (i) $\tau_1$ consists of $\mathbb{R}, \emptyset,$ and every interval $(-n, n)$, for $n$ any positive integer.
#
# We merely check all three conditions listed in the definition of a Topology (1.1.1)
#
# Condition 1: $\mathbb{R}$ and $\emptyset$ are members of $\tau$
#
# Condition 2: Below I demonstrate that all possible unions belong to $\tau$:
#
# $\mathbb{R} \bigcup \emptyset = \mathbb{R}, \mathbb{R} \bigcup (-n, n) = \mathbb{R}$
#
# $\emptyset \bigcup (-n, n) = (-n, n)$
#
# Finite and countably infinite unions of members of $\tau: U \in$ {$(-n,n): n$ a positive integer} are membes of $\tau$:
#
# $\bigcup_{U_n\in S} U_n = (-max(n), max(n))$ where S is finite and S $\subset$ {$U_n: (-n,n): n$ a positive integer}
#
# $\bigcup_{U_n\in S} U_n$ = $\mathbb{R}$ where S is infinite and S $\subseteq$ {$U_n: (-n,n): n$ a positive integer}
#
# Condition 3: Similarly for intersections (leaving out infinite intersections):
#
# $\mathbb{R} \cap \emptyset = \emptyset, \mathbb{R} \cap (-n, n) = (-n, n)$
#
# $\emptyset \cap (-n, n) = \emptyset$
#
# $(-n, n) \cap (-m, m) = (-min(m,n), min(m,n))$
#
# The proof of (ii) is analogous to the proof of (i) wherein one can replace $(-n, n)$ with $[-n, n]$.
#
# (iii)
#
# Condtion 1: Same as for proof of (i) above.
#
# Condition 2:
#
# $\mathbb{R} \bigcup \emptyset = \mathbb{R}, \mathbb{R} \bigcup [n, \infty) = \mathbb{R}$
#
# $\emptyset \bigcup [n, \infty) = [n, \infty)$
#
# $\bigcup_{U_n\in S} U_n = [min(n), \infty)$ where S is finite or countably infinite and S $\subseteq$ {$U_n: (n,\infty): n$ a positive integer}
#
# Condition 3:
#
# $\mathbb{R} \cap \emptyset = \emptyset, \mathbb{R} \cap [n, \infty) = [n, \infty)$
#
# $\emptyset \cap [n, \infty) = \emptyset$
#
# $[n, \infty) \cap [m, \infty) = [max(m,n), \infty)$

# %% [markdown]
# ## Chapter 6
#
# 6.1.11
#
# ii The assumption of the 2nd axiom of countability guarantees that the space (X, $\tau$) can be "generated" by a countable collection of basis sets. By the term "generated" I mean that their exist a collection of sets $\mathcal{B}$ (in this case a countable collection) such that every member of $\tau$ is a union of members of $\mathcal{B}$.
#
# By Proposition 2.3.3 for every x $\in$ X and every open set U that contains x there exist a B $\in \mathcal{B}$ such that x $\in$ B $\subseteq$ U. Thus the topology (X, $\tau$) is First Countable.
#
# Exercises 6.3
#
# 6.3.4
#
# Assume a Cauchy sequence in $\mathbb{R}^m$ {$w_n$ : n=1,2,3...}= {<$x_{1n}$, $x_{2n}$, ... $x_{mn}$> : n=1,2,3...}
#
# For any $\epsilon$ > 0 there exists an N such that d($w_n$, $w_p$) < $\epsilon$ when n $\ge$ N and p $\ge$ N
#
# $d^2$($w_n$, $w_p$) = $(x_{1n}-x_{1p})^2 + (x_{2n}-x_{2p})^2$ + ... + $(x_{mn}-x_{mp})^2 \le \epsilon^2$
#
# Therefore: $(x_{in}-x_{ip})^2 \le \epsilon^2$ for i = 1,2,...m
#
# $d(x_{in}, x_{ip}) = |x_{in}-x_{ip}| \le \epsilon$ for i = 1,2,...m and n $\ge$ N and p $\ge$ N
#
# This means that the sequence in $\mathbb{R}$, {$x_{in}$ : n=1,2,3...} is a Cauchy sequence and thus by 6.3.11 converges to a point in $\mathbb{R}$ call it $a_i$.
#
# Therefore {$w_n$} converges to a point in $\mathbb{R}^m$ call it <$a_{1}$, $a_{2}$, ... $a_{m}$>
#
# Thus $\mathbb{R}^m$ with the Euclidean metric is a complete metric space.
#
# 6.3.8
#
# Prove that for every $\epsilon > 0$ there exists a postive integer N such that:
# |$d(x_n, y_n) - d(x_m, y_m)| < \epsilon$ when $n \ge N$ and $m \ge N$ thus making {$d(x_n, y_n)$} a Cauchy sequence in $\mathbb{R}$ with the Euclidean metric.
#
# Since d is a metric we apply the triangle inequalty:
#
# $d(x_n, y_n) \le d(x_n, x_m) + d(x_m, y_n)$
#
# We apply the triangle inequality again
#
# $d(x_n, y_n) \le d(x_n, x_m) + d(x_m, y_m) + d(y_m, y_n)$
#
# Subtracting $d(x_m, y_m)$ from both sides:
#
# $d(x_n, y_n) - d(x_m, y_m) \le d(x_n, x_m) + d(y_m, y_n)$
#
# Since $d(a, b) = d(b, a)$ we know that:
#
# $d(x_m, y_m) - d(x_n, y_n) \le d(x_n, x_m) + d(y_m, y_n)$
#
# so
#
# $|d(x_n, y_n) - d(x_m, y_m)| \le d(x_n, x_m) + d(y_n, y_m)$
#
# Because {$x_n$} and {$y_n$} are Cauchy sequences we know that for every $\alpha > 0$
# there exist a positive integer N such that $d(x_n, x_m) < \alpha$ and $d(y_n, y_m) < \alpha$
# when $n \ge N$ and $m \ge N$.
#
# This implies that for the chosen N:
#
# $|d(x_n, y_n) - d(x_m, y_m)| \lt 2*\alpha$
#
# Finally let $\alpha = \epsilon / 2$
#
# 6.3.9 Fill in the missing details in the proof of Proposition 6.3.23
#
# Show that $d_1(\tilde{y}, \tilde{z})$ is not dependent on the choice of {$y_n$} in $\tilde{y}$ or {$z_n$} in $\tilde{z}$
#
# Assume that we have two sequences from $\tilde{y}$: {$y_n^1$} and {$y_n^2$} and two sequences from $\tilde{z}$: {$z_n^1$} and {$z_n^2$}. Furthermore sequences that are equivalent have the property that d($y_n^i$, $y_n^j$) -> 0.
#
# As elsewhere shown in the proof Cauchy sequences of the form {d($z_n$, $y_n$)} converge in $\mathbb{R}$. Note that the metric here ($d_1$) is the Euclidean metric and can be taken as the absolute value of the difference between the two values. So:
#
#
# There is a unique $\alpha \in \mathbb{R}$ such that for every $\epsilon$ > 0 there exists a positive integer N such that |$\alpha$ - d($z_n^1$, $y_n^1$)| < $\epsilon$ when n $\ge$ N
#
# There is a unique $\beta$ such that for every $\epsilon$ > 0 there exists a positive integer M such that |$\beta$ - d($z_n^2$, $y_n^2$)| < $\epsilon$ when n $\ge$ M
#
# For n $\ge$ Max(M, N):
#
# |$\alpha$ - d($z_n^1$, $y_n^1$)| + |$\beta$ - d($z_n^2$, $y_n^2$)| < $2 * \epsilon$
#
# Apply the triangle identity:
#
# |$\alpha$ - d($z_n^1$, $y_n^1$) - $\beta$ + d($z_n^2$, $y_n^2$)| < $2 * \epsilon$
#
# Note that:
#
# d($z_n^1$, $y_n^1$) $\le$ d($z_n^1$, $z_n^2$) + d($y_n^1$, $y_n^2$) + d($z_n^2$, $y_n^2$) or
# d($z_n^1$, $y_n^1$) - d($z_n^2$, $y_n^2$) $\le$ d($z_n^1$, $z_n^2$) + d($y_n^1$, $y_n^2$)
#
# So
#
# |$\alpha$ - $\beta$ + d($z_n^2$, $y_n^2$) - d($z_n^1$, $y_n^1$)| < $2 * \epsilon$
#
# For any $\gamma$/2 > 0 there exists a positive integer P such that:
#
# |d($z_n^2$, $y_n^2$) - d($z_n^1$, $y_n^1$)| $\le$ |d($z_n^2$, $y_n^2$)| + |d($z_n^1$, $y_n^1$)| $\le \gamma$ for n $\ge$ P
#
# So for n $\ge$ Max(M, N, P):
#
# |$\alpha$ - $\beta$ + $\gamma$| < $2 * \epsilon$
#
# |$\alpha$ - $\beta$ + $\gamma$| + $\gamma$ < $2 * \epsilon$ + $\gamma$
#
# and finally:
#
# |$\alpha$ - $\beta$| < $2 * \epsilon + \gamma$ thus showing that there is no non-zero difference between $\alpha$ and $\beta$ and therefore:
#
# {d($z_n^1$, $y_n^1$)} and {d($z_n^2$, $y_n^2$)} converge to the same value which we thus symbolize as $d_1$($\tilde{y}$,$\tilde{z}$)
#
#
# 6.4.1
#
# Assume an open set U $\subseteq$ X. For each a $\in$ X such that f(a) $\in$ U there exists an open ball: $B_\delta(f(a)) \subseteq$ U. The existance of $B_\delta(f(a))$ follows from Proposition 2.3.2. Furthermore let V be the set of members of the open ball: $B_{\delta/r}(a)$. Because f is a contraction mapping we know that d(f(x), f(a)) $\le$ r * d(a,x) and therefore f(V) $\subseteq$ $B_\delta(f(a))$ $\subseteq$ U.  So by Lemma 5.1.2 (ii) f is continuous.

# %% [markdown]
# ## Section 6.5 Baire Spaces
#
# 6.5.2 Prove Corollary 6.5.4
#
# It is important to note that if a subset A of a topological space (X, $\tau$) is nowhere dense then $X\backslash\bar{A}$ is open and dense.
#
# Assume that $X_n$ is nowhere dense in X.
#
# Then $X\backslash\bigcup_{n=1}^\infty X_n$ $\supseteq$ $X\backslash\bigcup_{n=1}^\infty$ $\bar{X}_n$
#
# $X\backslash\bigcup_{n=1}^\infty$ $\bar{X}_n$ = $\bigcap_{n=1}^\infty$ $X\backslash\bar{X_n}$
#
# Since each of the $X\backslash\bar{X_n}$ is open and dense then by Theorem 6.5.1 the intersection of all the $X\backslash\bar{X_n}$ is dense in X.  The premise of 6.5.4 however is that $X\backslash\bigcup_{n=1}^\infty X_n$ is empty. This leads to a contradication because the empty set is not dense (Note: This assertion is a little beyond me. I think the proof is that a limit point of the empty set would be a point such that every open set that contains the limit point would also contain a member of the empty set.  Every open set does contain the empty set (I think) but the empty set contains no members so it's impossible for a limit point of the empty set to exist by definition.). So at least one of the subsets $X_n$ must not be nowhere dense and thus must have a non-empty interior which is the same as saying that there exist a non-empty open set that is a subset of one of the $X_n$.
